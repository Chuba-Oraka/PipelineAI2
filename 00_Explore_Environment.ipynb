# %%
import tensorflow as tf
print('TensorFlow Version %s' % tf.__version__)
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# TensorFlow Version 1.13.1

# %%
import sys
print('Python Version %s' % sys.version)
# Out:
# Python Version 3.6.8 |Anaconda, Inc.| (default, Dec 30 2018, 01:22:34)
# [GCC 7.3.0]

# %%
# !pip list
# Out:
# Package                    Version
# -------------------------- --------
# absl-py                    0.7.1
# adal                       1.2.2
# alembic                    1.0.11
# ansiwrap                   0.8.4
# apache-beam                2.13.0
# asn1crypto                 0.24.0
# astor                      0.8.0
# async-generator            1.10
# attrs                      19.1.0
# avro-python3               1.9.0
# azure-common               1.1.23
# azure-datalake-store       0.0.47
# azure-storage-blob         2.1.0
# azure-storage-common       2.1.0
# backcall                   0.1.0
# bleach                     3.1.0
# boto3                      1.9.209
# botocore                   1.12.209
# cachetools                 3.1.1
# certifi                    2019.3.9
# cffi                       1.11.5
# chardet                    3.0.4
# Click                      7.0
# cloudpickle                1.2.1
# conda                      4.6.14
# configparser               3.7.4
# crcmod                     1.7
# cryptography               2.4.2
# cycler                     0.10.0
# databricks-cli             0.8.7
# decorator                  4.4.0
# defusedxml                 0.6.0
# dill                       0.2.9
# docker                     4.0.2
# docopt                     0.6.2
# docutils                   0.15.2
# entrypoints                0.3
# fairing                    0.5.3
# fastavro                   0.21.24
# fasteners                  0.15
# Flask                      1.1.1
# fsspec                     0.4.1
# future                     0.17.1
# gast                       0.2.2
# gcsfs                      0.3.0
# gitdb2                     2.0.5
# GitPython                  2.1.13
# google-api-core            1.14.2
# google-api-python-client   1.7.10
# google-apitools            0.5.28
# google-auth                1.6.3
# google-auth-httplib2       0.0.3
# google-auth-oauthlib       0.4.0
# google-cloud-bigquery      1.6.1
# google-cloud-bigtable      0.32.2
# google-cloud-core          1.0.3
# google-cloud-datastore     1.7.4
# google-cloud-pubsub        0.39.1
# google-cloud-storage       1.17.0
# google-resumable-media     0.3.2
# googleapis-common-protos   1.6.0
# gorilla                    0.3.0
# grpc-google-iam-v1         0.11.4
# grpcio                     1.22.0
# gunicorn                   19.9.0
# h5py                       2.9.0
# hdfs                       2.5.8
# httplib2                   0.12.0
# idna                       2.6
# ipykernel                  5.1.1
# ipython                    7.7.0
# ipython-genutils           0.2.0
# ipywidgets                 7.5.1
# itsdangerous               1.1.0
# jedi                       0.14.1
# Jinja2                     2.10.1
# jmespath                   0.9.4
# joblib                     0.13.2
# jsonschema                 3.0.1
# jupyter                    1.0.0
# jupyter-client             5.3.1
# jupyter-console            6.0.0
# jupyter-core               4.5.0
# jupyterhub                 0.9.4
# jupyterlab                 0.35.4
# jupyterlab-server          0.2.0
# Keras                      2.2.4
# Keras-Applications         1.0.8
# Keras-Preprocessing        1.1.0
# kfp                        0.1
# kiwisolver                 1.1.0
# kubernetes                 10.0.0
# Mako                       1.0.14
# Markdown                   3.1.1
# MarkupSafe                 1.1.1
# matplotlib                 3.1.1
# mistune                    0.8.4
# ml-metadata                0.13.2
# mlflow                     1.1.0
# mock                       2.0.0
# monotonic                  1.5
# nbconvert                  5.5.0
# nbformat                   4.4.0
# networkx                   2.3
# notebook                   6.0.0
# numpy                      1.17.0
# oauth2client               4.1.3
# oauthlib                   3.0.2
# pamela                     1.0.0
# pandas                     0.24.2
# pandocfilters              1.4.2
# papermill                  1.0.1
# parso                      0.5.1
# pbr                        5.4.1
# pexpect                    4.7.0
# pickleshare                0.7.5
# pip                        19.0.1
# prometheus-client          0.7.1
# prompt-toolkit             2.0.9
# protobuf                   3.9.0
# ptyprocess                 0.6.0
# pyarrow                    0.13.0
# pyasn1                     0.4.6
# pyasn1-modules             0.2.5
# pycosat                    0.6.3
# pycparser                  2.18
# pydot                      1.2.4
# Pygments                   2.4.2
# PyJWT                      1.6.4
# pyOpenSSL                  17.5.0
# pyparsing                  2.4.2
# pyrsistent                 0.15.4
# PySocks                    1.6.8
# python-dateutil            2.8.0
# python-editor              1.0.4
# python-oauth2              1.1.1
# pytz                       2019.2
# PyYAML                     3.13
# pyzmq                      18.0.2
# qtconsole                  4.5.2
# querystring-parser         1.2.4
# requests                   2.22.0
# requests-oauthlib          1.2.0
# requests-toolbelt          0.8.0
# rsa                        4.0
# ruamel-yaml                0.15.35
# s3transfer                 0.2.1
# scikit-learn               0.21.2
# scipy                      1.1.0
# Send2Trash                 1.5.0
# setuptools                 39.0.1
# simplejson                 3.16.0
# six                        1.11.0
# smmap2                     2.0.5
# SQLAlchemy                 1.3.6
# sqlparse                   0.3.0
# tabulate                   0.8.3
# tenacity                   5.0.4
# tensorboard                1.13.1
# tensorflow                 1.13.1
# tensorflow-data-validation 0.13.1
# tensorflow-estimator       1.13.0
# tensorflow-metadata        0.13.0
# tensorflow-model-analysis  0.13.1
# tensorflow-transform       0.13.0
# termcolor                  1.1.0
# terminado                  0.8.2
# testpath                   0.4.2
# textwrap3                  0.9.2
# tfx                        0.13.0
# tornado                    5.1.1
# tqdm                       4.33.0
# traitlets                  4.3.2
# uritemplate                3.0.0
# urllib3                    1.24.2
# wcwidth                    0.1.7
# webencodings               0.5.1
# websocket-client           0.56.0
# Werkzeug                   0.15.5
# wheel                      0.31.0
# widgetsnbextension         3.5.1
# xgboost                    0.90
# You are using pip version 19.0.1, however version 19.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %%bash
# conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# absl-py                   0.7.1                    pypi_0    pypi
# adal                      1.2.2                    pypi_0    pypi
# alembic                   1.0.11                   pypi_0    pypi
# ansiwrap                  0.8.4                    pypi_0    pypi
# apache-beam               2.13.0                   pypi_0    pypi
# asn1crypto                0.24.0                   py36_0
# astor                     0.8.0                    pypi_0    pypi
# async-generator           1.10                     pypi_0    pypi
# attrs                     19.1.0                   pypi_0    pypi
# avro-python3              1.9.0                    pypi_0    pypi
# azure-common              1.1.23                   pypi_0    pypi
# azure-datalake-store      0.0.47                   pypi_0    pypi
# azure-storage-blob        2.1.0                    pypi_0    pypi
# azure-storage-common      2.1.0                    pypi_0    pypi
# backcall                  0.1.0                    pypi_0    pypi
# bleach                    3.1.0                    pypi_0    pypi
# boto3                     1.9.209                  pypi_0    pypi
# botocore                  1.12.209                 pypi_0    pypi
# ca-certificates           2019.1.23                     0
# cachetools                3.1.1                    pypi_0    pypi
# certifi                   2019.3.9                 py36_0
# cffi                      1.11.5           py36h9745a5d_0
# chardet                   3.0.4            py36h0f667ec_1
# click                     7.0                      pypi_0    pypi
# cloudpickle               1.2.1                    pypi_0    pypi
# conda                     4.6.14                   py36_0
# conda-env                 2.6.0                h36134e3_1
# configparser              3.7.4                    pypi_0    pypi
# crcmod                    1.7                      pypi_0    pypi
# cryptography              2.4.2                    pypi_0    pypi
# cycler                    0.10.0                   pypi_0    pypi
# databricks-cli            0.8.7                    pypi_0    pypi
# decorator                 4.4.0                    pypi_0    pypi
# defusedxml                0.6.0                    pypi_0    pypi
# dill                      0.2.9                    pypi_0    pypi
# docker                    4.0.2                    pypi_0    pypi
# docopt                    0.6.2                    pypi_0    pypi
# docutils                  0.15.2                   pypi_0    pypi
# entrypoints               0.3                      pypi_0    pypi
# fairing                   0.5.3                    pypi_0    pypi
# fastavro                  0.21.24                  pypi_0    pypi
# fasteners                 0.15                     pypi_0    pypi
# flask                     1.1.1                    pypi_0    pypi
# fsspec                    0.4.1                    pypi_0    pypi
# future                    0.17.1                   pypi_0    pypi
# gast                      0.2.2                    pypi_0    pypi
# gcsfs                     0.3.0                    pypi_0    pypi
# gitdb2                    2.0.5                    pypi_0    pypi
# gitpython                 2.1.13                   pypi_0    pypi
# google-api-core           1.14.2                   pypi_0    pypi
# google-api-python-client  1.7.10                   pypi_0    pypi
# google-apitools           0.5.28                   pypi_0    pypi
# google-auth               1.6.3                    pypi_0    pypi
# google-auth-httplib2      0.0.3                    pypi_0    pypi
# google-auth-oauthlib      0.4.0                    pypi_0    pypi
# google-cloud-bigquery     1.6.1                    pypi_0    pypi
# google-cloud-bigtable     0.32.2                   pypi_0    pypi
# google-cloud-core         1.0.3                    pypi_0    pypi
# google-cloud-datastore    1.7.4                    pypi_0    pypi
# google-cloud-pubsub       0.39.1                   pypi_0    pypi
# google-cloud-storage      1.17.0                   pypi_0    pypi
# google-resumable-media    0.3.2                    pypi_0    pypi
# googleapis-common-protos  1.6.0                    pypi_0    pypi
# gorilla                   0.3.0                    pypi_0    pypi
# grpc-google-iam-v1        0.11.4                   pypi_0    pypi
# grpcio                    1.22.0                   pypi_0    pypi
# gunicorn                  19.9.0                   pypi_0    pypi
# h5py                      2.9.0                    pypi_0    pypi
# hdfs                      2.5.8                    pypi_0    pypi
# httplib2                  0.12.0                   pypi_0    pypi
# idna                      2.6              py36h82fb2a8_1
# ipykernel                 5.1.1                    pypi_0    pypi
# ipython                   7.7.0                    pypi_0    pypi
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipywidgets                7.5.1                    pypi_0    pypi
# itsdangerous              1.1.0                    pypi_0    pypi
# jedi                      0.14.1                   pypi_0    pypi
# jinja2                    2.10.1                   pypi_0    pypi
# jmespath                  0.9.4                    pypi_0    pypi
# joblib                    0.13.2                   pypi_0    pypi
# jsonschema                3.0.1                    pypi_0    pypi
# jupyter                   1.0.0                    pypi_0    pypi
# jupyter-client            5.3.1                    pypi_0    pypi
# jupyter-console           6.0.0                    pypi_0    pypi
# jupyter-core              4.5.0                    pypi_0    pypi
# jupyterhub                0.9.4                    pypi_0    pypi
# jupyterlab                0.35.4                   pypi_0    pypi
# jupyterlab-server         0.2.0                    pypi_0    pypi
# keras                     2.2.4                    pypi_0    pypi
# keras-applications        1.0.8                    pypi_0    pypi
# keras-preprocessing       1.1.0                    pypi_0    pypi
# kfp                       0.1                      pypi_0    pypi
# kiwisolver                1.1.0                    pypi_0    pypi
# kubernetes                10.0.0                   pypi_0    pypi
# libedit                   3.1.20181209         hc058e9b_0
# libffi                    3.2.1                hd88cf55_4
# libgcc-ng                 8.2.0                hdf63c60_1
# libstdcxx-ng              8.2.0                hdf63c60_1
# mako                      1.0.14                   pypi_0    pypi
# markdown                  3.1.1                    pypi_0    pypi
# markupsafe                1.1.1                    pypi_0    pypi
# matplotlib                3.1.1                    pypi_0    pypi
# mistune                   0.8.4                    pypi_0    pypi
# ml-metadata               0.13.2                   pypi_0    pypi
# mlflow                    1.1.0                    pypi_0    pypi
# mock                      2.0.0                    pypi_0    pypi
# monotonic                 1.5                      pypi_0    pypi
# nbconvert                 5.5.0                    pypi_0    pypi
# nbformat                  4.4.0                    pypi_0    pypi
# ncurses                   6.1                  he6710b0_1
# networkx                  2.3                      pypi_0    pypi
# notebook                  6.0.0                    pypi_0    pypi
# numpy                     1.17.0                   pypi_0    pypi
# oauth2client              4.1.3                    pypi_0    pypi
# oauthlib                  3.0.2                    pypi_0    pypi
# openssl                   1.1.1c               h7b6447c_1
# pamela                    1.0.0                    pypi_0    pypi
# pandas                    0.24.2                   pypi_0    pypi
# pandocfilters             1.4.2                    pypi_0    pypi
# papermill                 1.0.1                    pypi_0    pypi
# parso                     0.5.1                    pypi_0    pypi
# pbr                       5.4.1                    pypi_0    pypi
# pexpect                   4.7.0                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pip                       19.0.1                   pypi_0    pypi
# prometheus-client         0.7.1                    pypi_0    pypi
# prompt-toolkit            2.0.9                    pypi_0    pypi
# protobuf                  3.9.0                    pypi_0    pypi
# ptyprocess                0.6.0                    pypi_0    pypi
# pyarrow                   0.13.0                   pypi_0    pypi
# pyasn1                    0.4.6                    pypi_0    pypi
# pyasn1-modules            0.2.5                    pypi_0    pypi
# pycosat                   0.6.3            py36h0a5515d_0
# pycparser                 2.18             py36hf9f622e_1
# pydot                     1.2.4                    pypi_0    pypi
# pygments                  2.4.2                    pypi_0    pypi
# pyjwt                     1.6.4                    pypi_0    pypi
# pyopenssl                 17.5.0           py36h20ba746_0
# pyparsing                 2.4.2                    pypi_0    pypi
# pyrsistent                0.15.4                   pypi_0    pypi
# pysocks                   1.6.8                    py36_0
# python                    3.6.8                h0371630_0
# python-dateutil           2.8.0                    pypi_0    pypi
# python-editor             1.0.4                    pypi_0    pypi
# python-oauth2             1.1.1                    pypi_0    pypi
# pytz                      2019.2                   pypi_0    pypi
# pyyaml                    3.13                     pypi_0    pypi
# pyzmq                     18.0.2                   pypi_0    pypi
# qtconsole                 4.5.2                    pypi_0    pypi
# querystring-parser        1.2.4                    pypi_0    pypi
# readline                  7.0                  ha6073c6_4
# requests                  2.22.0                   pypi_0    pypi
# requests-oauthlib         1.2.0                    pypi_0    pypi
# requests-toolbelt         0.8.0                    pypi_0    pypi
# rsa                       4.0                      pypi_0    pypi
# ruamel_yaml               0.15.35          py36h14c3975_1
# s3transfer                0.2.1                    pypi_0    pypi
# scikit-learn              0.21.2                   pypi_0    pypi
# scipy                     1.1.0                    pypi_0    pypi
# send2trash                1.5.0                    pypi_0    pypi
# setuptools                39.0.1                   py36_0
# simplejson                3.16.0                   pypi_0    pypi
# six                       1.11.0           py36h372c433_1
# smmap2                    2.0.5                    pypi_0    pypi
# sqlalchemy                1.3.6                    pypi_0    pypi
# sqlite                    3.28.0               h7b6447c_0
# sqlparse                  0.3.0                    pypi_0    pypi
# tabulate                  0.8.3                    pypi_0    pypi
# tenacity                  5.0.4                    pypi_0    pypi
# tensorboard               1.13.1                   pypi_0    pypi
# tensorflow                1.13.1                   pypi_0    pypi
# tensorflow-data-validation 0.13.1                   pypi_0    pypi
# tensorflow-estimator      1.13.0                   pypi_0    pypi
# tensorflow-metadata       0.13.0                   pypi_0    pypi
# tensorflow-model-analysis 0.13.1                   pypi_0    pypi
# tensorflow-transform      0.13.0                   pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.8.2                    pypi_0    pypi
# testpath                  0.4.2                    pypi_0    pypi
# textwrap3                 0.9.2                    pypi_0    pypi
# tfx                       0.13.0                   pypi_0    pypi
# tk                        8.6.8                hbc83047_0
# tornado                   5.1.1                    pypi_0    pypi
# tqdm                      4.33.0                   pypi_0    pypi
# traitlets                 4.3.2                    pypi_0    pypi
# uritemplate               3.0.0                    pypi_0    pypi
# urllib3                   1.24.2                   pypi_0    pypi
# wcwidth                   0.1.7                    pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          0.56.0                   pypi_0    pypi
# werkzeug                  0.15.5                   pypi_0    pypi
# wheel                     0.31.0                   py36_0
# widgetsnbextension        3.5.1                    pypi_0    pypi
# xgboost                   0.90                     pypi_0    pypi
# xz                        5.2.4                h14c3975_4
# yaml                      0.1.7                had09818_2
# zlib                      1.2.11               ha838bed_2

# %%
import tensorflow as tf

tpu_name = 'tpu-us-central1-a-00'
tpu_zone = 'us-central1-a'
tpu_project = 'pipelineai2'

tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(
            tpu=tpu_name,
            zone=tpu_zone,
            project=tpu_project)

print(tpu_cluster_resolver.get_master())
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-b30ec37ef4b7> in <module>
#      10             project=tpu_project)
#      11
# ---> 12 print(tpu_cluster_resolver.get_master())
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/distribute/cluster_resolver/tpu_cluster_resolver.py in get_master(self)
#     352
#     353   def get_master(self):
# --> 354     return self.master()
#     355
#     356   def get_job_name(self):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/distribute/cluster_resolver/tpu_cluster_resolver.py in master(self, task_type, task_index, rpc_layer)
#     331     if self._shouldResolve():
#     332       # We are going to communicate with the Cloud TPU APIs to get a Cluster.
# --> 333       cluster_spec = self.cluster_spec()
#     334       if task_type is not None and task_index is not None:
#     335         # task_type and task_index is from the function parameter
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/distribute/cluster_resolver/tpu_cluster_resolver.py in cluster_spec(self)
#     392       if 'state' in response and response['state'] != 'READY':
#     393         raise RuntimeError('TPU "%s" is not yet ready; state: "%s"' %
# --> 394                            (compat.as_text(self._tpu), response['state']))
#     395
#     396       if 'health' in response and response['health'] != 'HEALTHY':
#
# RuntimeError: TPU "tpu-us-central1-a-00" is not yet ready; state: "STOPPED"

# %%
# %%html
#
# <iframe src="https://pipeline.ai" width="800px" height="600px"/>
# Out:
# <iframe src="https://pipeline.ai" width="800px" height="600px"/>
